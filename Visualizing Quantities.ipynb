# %%
import pandas as pd

# %%
data = pd.read_excel('birds.xlsx')

# %%
data
# Out:
#      Name                ScientificName                Category  \
# 0     NaN  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1     NaN        Fulvous whistling-duck     Dendrocygna bicolor
# 2     NaN                    Snow goose      Anser caerulescens
# 3     NaN                  Ross's goose            Anser rossii
# 4     NaN   Greater white-fronted goose         Anser albifrons
# ..    ...                           ...                     ...
# 438   NaN                 Blue grosbeak      Passerina caerulea
# 439   NaN                Lazuli bunting        Passerina amoena
# 440   NaN                Indigo bunting        Passerina cyanea
# 441   NaN               Painted bunting         Passerina ciris
# 442   NaN                    Dickcissel         Spiza americana
#
#                      Order         Family         Genus ConservationStatus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae              Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae              Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae              Anser
# ..                     ...            ...           ...                ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae          Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae          Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae          Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae          Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae              Spiza
#
#     MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan  \
# 0          LC       47.0         56.0        652.0       1020.0         76.0
# 1          LC       45.0         53.0        712.0       1050.0         85.0
# 2          LC       64.0         79.0       2050.0       4050.0        135.0
# 3          LC       57.3         64.0       1066.0       1567.0        113.0
# 4          LC       64.0         81.0       1930.0       3310.0        130.0
# ..        ...        ...          ...          ...          ...          ...
# 438        LC       14.0         19.0         26.0         31.5         26.0
# 439        LC       13.0         15.0         13.0         18.0         22.0
# 440        LC       11.5         15.0         11.2         21.4         18.0
# 441        LC       12.0         14.0         13.0         19.0         21.0
# 442        LC       14.0         16.0         25.6         38.4         24.8
#
#      Unnamed: 13
# 0           94.0
# 1           93.0
# 2          165.0
# 3          116.0
# 4          165.0
# ..           ...
# 438         29.0
# 439         22.0
# 440         23.0
# 441         23.0
# 442         26.0
#
# [443 rows x 14 columns]

# %%
data.head()
# Out:
#    Name                ScientificName                Category  \
# 0   NaN  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1   NaN        Fulvous whistling-duck     Dendrocygna bicolor
# 2   NaN                    Snow goose      Anser caerulescens
# 3   NaN                  Ross's goose            Anser rossii
# 4   NaN   Greater white-fronted goose         Anser albifrons
#
#                    Order        Family     Genus ConservationStatus MinLength  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Dendrocygna        LC
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Dendrocygna        LC
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae              Anser        LC
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae              Anser        LC
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae              Anser        LC
#
#    MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan  Unnamed: 13
# 0       47.0         56.0        652.0       1020.0         76.0         94.0
# 1       45.0         53.0        712.0       1050.0         85.0         93.0
# 2       64.0         79.0       2050.0       4050.0        135.0        165.0
# 3       57.3         64.0       1066.0       1567.0        113.0        116.0
# 4       64.0         81.0       1930.0       3310.0        130.0        165.0

# %%
wingspan = data['MinWingspan']

# %%
wingspan.plot()
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plot

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (cm)')
plt.xlabel('Birds')
plt.xticks(rotation=45)
x=data['Name']
y=data['MinWingspan']
plt.plot(x,y,'bo')
plt.show()

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.xticks(rotation=45)
x = data['Name'] 
y = data['MaxWingspan']

plt.plot(x, y)

plt.show()

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)

for i in range(len(data)):
    x = data['Name'][i]
    y = data['MaxWingspan'][i]
    plt.plot(x,y,'bo')
    if data['MaxWingspan'][i]>500:
        plt.text(x, y * (1 - 0.05), data['Name'][i], fontsize=12)
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)

for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    plt.plot(x, y, 'bo')
    if birds['MaxWingspan'][i] > 500:
        plt.text(x, y * (1 - 0.05), birds['Name'][i], fontsize=12)
    
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
birds = pd.read_excel('birds.xlsx')

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)
for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    if birds['Name'][i] not in ['Bald eagle', 'Prairie falcon']:
        plt.plot(x, y, 'bo')
plt.show()

# %%
birds.plot(x='Category',
        kind='bar',
        stacked=True,
        title='Birds of Minnesota')
# Out:
# <AxesSubplot: title={'center': 'Birds of Minnesota'}, xlabel='Category'>

# %%
category_count = birds.value_counts(birds['Category'].values, sort=True)
plt.rcParams['figure.figsize'] = [12, 200]
category_count.plot.barh()
# Out:
# <AxesSubplot: >

# %%
minLength = birds['MinLength']
maxLength = birds['MaxLength']
category = birds['Category']

plt.barh(category, maxLength)
plt.barh(category, minLength)

plt.show()
